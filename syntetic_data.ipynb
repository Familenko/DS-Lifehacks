# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification, make_regression

# %%
X, y = make_classification(n_samples=1000, n_features=5, n_classes=2, 
                           weights=[0.9, 0.1], random_state=42)

df = pd.DataFrame(X, columns=[f'feature_{i}' for i in range(1, 6)])
df['target'] = y

df
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  target
# 0    -0.439643   0.542547  -0.822420   0.401366  -0.854840       0
# 1    -1.320268  -0.451656  -1.147691   0.217991   2.515569       0
# 2    -0.902414  -0.301790  -2.084113   0.152282   1.702509       0
# 3    -1.658183   1.183085   1.112688   1.104253  -1.115765       0
# 4    -1.598711   0.169268  -0.926698   0.603763   1.296845       0
# ..         ...        ...        ...        ...        ...     ...
# 995  -0.766350   0.768369   1.039112   0.615481  -1.056899       0
# 996  -2.847457   1.841002  -1.239107   1.805803  -1.450448       0
# 997  -1.508334   1.133203  -0.234408   1.031522  -1.154236       0
# 998   0.886925  -0.222946  -1.308820  -0.396177  -0.404278       0
# 999  -2.747104   1.850430  -0.193826   1.777419  -1.580834       0
#
# [1000 rows x 6 columns]

# %%
X, y = make_regression(n_samples=1000, n_features=5, n_informative=5,
                          random_state=42)

df = pd.DataFrame(X, columns=[f'feature_{i}' for i in range(1, 6)])    
df['target'] = y
df
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5      target
# 0    -1.039906   0.612774  -1.053416  -0.623769   1.914031  -24.880512
# 1     0.317453  -0.332860  -0.093387  -0.529332  -1.514470  -57.915143
# 2     0.538910  -1.037246  -0.190339  -0.875618  -1.382800  -78.689966
# 3    -1.776246  -0.080600  -0.833056   0.915390  -0.549540  -57.187044
# 4    -0.223466  -0.349317  -0.019420  -0.303180   0.799942   -0.172766
# ..         ...        ...        ...        ...        ...         ...
# 995   0.758929   0.281191   0.104201  -0.062593  -0.753965    2.459681
# 996   0.027313  -0.047371  -1.582177  -0.940399  -0.560761 -114.131516
# 997   0.965397   1.236131   0.088658   0.197316  -0.617652   34.168651
# 998   0.648710  -0.167118   0.146714   1.206509  -0.816936   28.822587
# 999  -2.391956   0.844774  -0.005560   1.178513  -1.373403  -24.700614
#
# [1000 rows x 6 columns]
