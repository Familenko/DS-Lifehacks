# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
california_housing = fetch_california_housing()
df = pd.DataFrame(california_housing.data, columns=california_housing.feature_names)
df['MedHouseVal'] = california_housing.target

# %%
def corr_df(df):
    corr_mtx = df.corr()
    mask_mtx = np.zeros_like(corr_mtx)
    np.fill_diagonal(mask_mtx, 1)
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df.corr(),
                cmap='coolwarm',
                center=0,
                annot=True,
                fmt='.2f',
                linewidth=0.5,
                square=True,
                mask=mask_mtx,
                ax=ax)

# %%
corr_df(df)

# %%
def corr_df(df):
    mtx = df.corr(numeric_only=True)
    fig, ax = plt.subplots(figsize=(8, 6))

    sns.heatmap(mtx,
    cmap='coolwarm',
    annot=True,
    fmt=".2f",
    linewidth=.5,
    mask=np.triu(np.ones_like(mtx, dtype=bool)),
    square=True,
    cbar=True,
    ax=ax)

    plt.show()

# %%
corr_df(df)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b1999_row0_col0, #T_b1999_row1_col1, #T_b1999_row2_col2, #T_b1999_row3_col3, #T_b1999_row4_col4, #T_b1999_row5_col5, #T_b1999_row6_col6, #T_b1999_row7_col7, #T_b1999_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b1999_row0_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b1999_row0_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b1999_row0_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b1999_row0_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b1999_row0_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b1999_row0_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_b1999_row0_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b1999_row0_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Якщо ранг менший, ніж кількість стовпців, то є лінійна залежність

# %%
rank = np.linalg.matrix_rank(df.values)
print(f'Rank: {rank}, Number of columns: {df.shape[1]}')
# Out:
# Rank: 9, Number of columns: 9
