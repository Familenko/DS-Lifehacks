# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
california_housing = fetch_california_housing()
df = pd.DataFrame(california_housing.data, columns=california_housing.feature_names)
df['MedHouseVal'] = california_housing.target

# %%
def corr_df(df):
    corr_mtx = df.corr()
    mask_mtx = np.zeros_like(corr_mtx)
    np.fill_diagonal(mask_mtx, 1)
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df.corr(),
                cmap='coolwarm',
                center=0,
                annot=True,
                fmt='.2f',
                linewidth=0.5,
                square=True,
                mask=mask_mtx,
                ax=ax)

# %%
corr_df(df)

# %%
def corr_df(df):
    mtx = df.corr(numeric_only=True)
    fig, ax = plt.subplots(figsize=(8, 6))

    sns.heatmap(mtx,
    cmap='coolwarm',
    annot=True,
    fmt=".2f",
    linewidth=.5,
    mask=np.triu(np.ones_like(mtx, dtype=bool)),
    square=True,
    cbar=True,
    ax=ax)

    plt.show()

# %%
corr_df(df)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d3168_row0_col0, #T_d3168_row1_col1, #T_d3168_row2_col2, #T_d3168_row3_col3, #T_d3168_row4_col4, #T_d3168_row5_col5, #T_d3168_row6_col6, #T_d3168_row7_col7, #T_d3168_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d3168_row0_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d3168_row0_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_d3168_row0_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d3168_row0_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_d3168_row0_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d3168_row0_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_d3168_row0_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_d3168_row0_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_d3168_row1_col0, #T_d3168_row1_col2, #T_d3168_row1_col3, #T_d3168_row1_col4, #T_d3168_row4_col1, #T_d3168_row6_col7, #T_d3168_row6_col8, #T_d3168_row7_col6, #T_d3168_row8_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d3168_row1_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d3168_row1_col6, #T_d3168_row3_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_d3168_row1_col7, #T_d3168_row4_col6 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_d3168_row1_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_d3168_row2_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_d3168_row2_col1, #T_d3168_row4_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d3168_row2_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_d3168_row2_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d3168_row2_col5, #T_d3168_row3_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d3168_row2_col6 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_d3168_row2_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_d3168_row2_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_d3168_row3_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_d3168_row3_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d3168_row3_col2 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_d3168_row3_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_d3168_row3_col6 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_d3168_row3_col8, #T_d3168_row7_col3, #T_d3168_row7_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d3168_row4_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d3168_row4_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d3168_row4_col5, #T_d3168_row7_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d3168_row4_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_d3168_row4_col8, #T_d3168_row5_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d3168_row5_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_d3168_row5_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_d3168_row5_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d3168_row5_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d3168_row5_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_d3168_row5_col6, #T_d3168_row5_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_d3168_row6_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d3168_row6_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_d3168_row6_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_d3168_row6_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d3168_row6_col4, #T_d3168_row7_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_d3168_row6_col5, #T_d3168_row7_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d3168_row7_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d3168_row7_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_d3168_row8_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_d3168_row8_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_d3168_row8_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_d3168_row8_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d3168_row8_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_d3168_row8_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_d3168_row8_col7 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# </style>
# <table id="T_d3168">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3168_level0_col0" class="col_heading level0 col0" >MedInc</th>
#       <th id="T_d3168_level0_col1" class="col_heading level0 col1" >HouseAge</th>
#       <th id="T_d3168_level0_col2" class="col_heading level0 col2" >AveRooms</th>
#       <th id="T_d3168_level0_col3" class="col_heading level0 col3" >AveBedrms</th>
#       <th id="T_d3168_level0_col4" class="col_heading level0 col4" >Population</th>
#       <th id="T_d3168_level0_col5" class="col_heading level0 col5" >AveOccup</th>
#       <th id="T_d3168_level0_col6" class="col_heading level0 col6" >Latitude</th>
#       <th id="T_d3168_level0_col7" class="col_heading level0 col7" >Longitude</th>
#       <th id="T_d3168_level0_col8" class="col_heading level0 col8" >MedHouseVal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3168_level0_row0" class="row_heading level0 row0" >MedInc</th>
#       <td id="T_d3168_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d3168_row0_col1" class="data row0 col1" >-0.119034</td>
#       <td id="T_d3168_row0_col2" class="data row0 col2" >0.326895</td>
#       <td id="T_d3168_row0_col3" class="data row0 col3" >-0.062040</td>
#       <td id="T_d3168_row0_col4" class="data row0 col4" >0.004834</td>
#       <td id="T_d3168_row0_col5" class="data row0 col5" >0.018766</td>
#       <td id="T_d3168_row0_col6" class="data row0 col6" >-0.079809</td>
#       <td id="T_d3168_row0_col7" class="data row0 col7" >-0.015176</td>
#       <td id="T_d3168_row0_col8" class="data row0 col8" >0.688075</td>
#     </tr>
#     <tr>
#       <th id="T_d3168_level0_row1" class="row_heading level0 row1" >HouseAge</th>
#       <td id="T_d3168_row1_col0" class="data row1 col0" >-0.119034</td>
#       <td id="T_d3168_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d3168_row1_col2" class="data row1 col2" >-0.153277</td>
#       <td id="T_d3168_row1_col3" class="data row1 col3" >-0.077747</td>
#       <td id="T_d3168_row1_col4" class="data row1 col4" >-0.296244</td>
#       <td id="T_d3168_row1_col5" class="data row1 col5" >0.013191</td>
#       <td id="T_d3168_row1_col6" class="data row1 col6" >0.011173</td>
#       <td id="T_d3168_row1_col7" class="data row1 col7" >-0.108197</td>
#       <td id="T_d3168_row1_col8" class="data row1 col8" >0.105623</td>
#     </tr>
#     <tr>
#       <th id="T_d3168_level0_row2" class="row_heading level0 row2" >AveRooms</th>
#       <td id="T_d3168_row2_col0" class="data row2 col0" >0.326895</td>
#       <td id="T_d3168_row2_col1" class="data row2 col1" >-0.153277</td>
#       <td id="T_d3168_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d3168_row2_col3" class="data row2 col3" >0.847621</td>
#       <td id="T_d3168_row2_col4" class="data row2 col4" >-0.072213</td>
#       <td id="T_d3168_row2_col5" class="data row2 col5" >-0.004852</td>
#       <td id="T_d3168_row2_col6" class="data row2 col6" >0.106389</td>
#       <td id="T_d3168_row2_col7" class="data row2 col7" >-0.027540</td>
#       <td id="T_d3168_row2_col8" class="data row2 col8" >0.151948</td>
#     </tr>
#     <tr>
#       <th id="T_d3168_level0_row3" class="row_heading level0 row3" >AveBedrms</th>
#       <td id="T_d3168_row3_col0" class="data row3 col0" >-0.062040</td>
#       <td id="T_d3168_row3_col1" class="data row3 col1" >-0.077747</td>
#       <td id="T_d3168_row3_col2" class="data row3 col2" >0.847621</td>
#       <td id="T_d3168_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d3168_row3_col4" class="data row3 col4" >-0.066197</td>
#       <td id="T_d3168_row3_col5" class="data row3 col5" >-0.006181</td>
#       <td id="T_d3168_row3_col6" cla
